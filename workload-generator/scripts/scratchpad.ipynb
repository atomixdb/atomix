# %%
import re
import json
import time
import signal

from subprocess import Popen
from yanniszark_common.cmdutils import run, check_output

# %%
# DB = "kv_store"
# PRIMARY_MASTER = "172.18.0.2"
# SECONDARY_MASTER = "172.18.0.3"
# PRIMARY_CONTAINER = "yb-primary"
# SECONDARY_CONTAINERS = ["yb-secondary-1", "yb-secondary-2"]

# %%
def docker_check_output(container, cmd):
    return check_output(["docker", "exec", container, "bash", "-c", cmd])

def get_safe_time_info():
    """Get cross-cluster safe time info from the secondary cluster.

    Returns:
        dict: Dictionary containing:
            - namespace_id (str): ID of the namespace (e.g. '000034cb000030008000000000000000')
            - namespace_name (str): Name of the namespace (e.g. 'yugabyte')
            - safe_time (str): Safe time in human readable format (e.g. '2025-06-23 21:24:52.764103')
            - safe_time_epoch (str): Safe time in epoch microseconds (e.g. '1750713892764103')
            - safe_time_lag_sec (str): Lag in seconds between clusters (e.g. '0.64')
            - safe_time_skew_sec (str): Clock skew in seconds between clusters (e.g. '0.30')
    """
    safe_time_info = docker_check_output(
        SECONDARY_CONTAINERS[0],
        f"./bin/yb-admin --master_addresses {SECONDARY_MASTER} get_xcluster_safe_time include_lag_and_skew"
    )
    safe_time_info = json.loads(safe_time_info.strip())

    if len(safe_time_info) != 1:
        raise ValueError(f"Expected exactly 1 safe time info entry, got {len(safe_time_info)}")

    return safe_time_info[0]

# %%
# Create table on primary
docker_check_output(
    PRIMARY_CONTAINER,
    f"""ysqlsh -h {PRIMARY_MASTER} -c "
        CREATE TABLE {DB} (
            k TEXT,
            v TEXT,
            PRIMARY KEY (k ASC)
        ) SPLIT AT VALUES (('d'), ('m'), ('t'));"
    """
)

# Create table on secondary
docker_check_output(
    SECONDARY_CONTAINERS[0],
    f"""ysqlsh -h {SECONDARY_MASTER} -c "
        CREATE TABLE {DB} (
            k TEXT,
            v TEXT,
            PRIMARY KEY (k ASC)
        ) SPLIT AT VALUES (('d'), ('m'), ('t'));"
    """
)



# Create snapshot schedule on secondary
docker_check_output(
    SECONDARY_CONTAINERS[0],
    f"./bin/yb-admin --master_addresses {SECONDARY_MASTER} create_snapshot_schedule 1 10 ysql.yugabyte"
)

# Get table ID
# Example output:
# yugabyte.kv_store [ysql_schema=public] [000034cb000030008000000000004000]
table_id_output = docker_check_output(
    PRIMARY_CONTAINER,
    f"./bin/yb-admin --master_addresses {PRIMARY_MASTER} list_tables | grep {DB}"
)
table_id = table_id_output.strip()
# Extract the table ID from the output using regex
table_id = re.search(r"\[([0-9a-f]+)\]$", table_id_output).group(1)

print(f"Table ID: '{table_id}'")

# Get bootstrap ID
# Example output:
# table id: 000034cb000030008000000000004000, CDC bootstrap id: de0b5affa1d0a6acbd42ab48a22e653f
bootstrap_output = docker_check_output(
    PRIMARY_CONTAINER,
    f"./bin/yb-admin --master_addresses {PRIMARY_MASTER} bootstrap_cdc_producer {table_id}"
)
# Extract the bootstrap ID from the output using regex
bootstrap_id = re.search(r"CDC bootstrap id: ([0-9a-f]+)", bootstrap_output).group(1)

print(f"Bootstrap ID: '{bootstrap_id}'")

# Set up universe replication on the first secondary
docker_check_output(
    SECONDARY_CONTAINERS[0],
    f"./bin/yb-admin --master_addresses {SECONDARY_MASTER} setup_universe_replication kv_store_replication {PRIMARY_MASTER} {table_id} {bootstrap_id} transactional"
)

# Set the secondary cluster to STANDBY mode
docker_check_output(
    SECONDARY_CONTAINERS[0],
    f"./bin/yb-admin --master_addresses {SECONDARY_MASTER} change_xcluster_role STANDBY"
)

safe_time_info = get_safe_time_info()
print(safe_time_info)

# %%
class YugabyteDB:

    PRIMARY_MASTER = "172.18.0.2"
    SECONDARY_MASTER = "172.18.0.3"
    PRIMARY_CONTAINER = "yb-primary"
    SECONDARY_CONTAINERS = ["yb-secondary-1", "yb-secondary-2"]

    def __init__(self):
        self.__compose_process = None

    def setup(self):
        self.__start_docker_compose()
        # Create table on primary
        docker_check_output(
            self.PRIMARY_CONTAINER,
            f"""ysqlsh -h {self.PRIMARY_MASTER} -c "
                CREATE TABLE {self.DB} (
                    k TEXT,
                    v TEXT,
                    PRIMARY KEY (k ASC)
                ) SPLIT AT VALUES (('d'), ('m'), ('t'));"
            """
        )

        # Create table on secondary
        docker_check_output(
            self.SECONDARY_CONTAINERS[0],
            f"""ysqlsh -h {self.SECONDARY_MASTER} -c "
                CREATE TABLE {self.DB} (
                    k TEXT,
                    v TEXT,
                    PRIMARY KEY (k ASC)
                ) SPLIT AT VALUES (('d'), ('m'), ('t'));"
            """
        )



        # Create snapshot schedule on secondary
        docker_check_output(
            self.SECONDARY_CONTAINERS[0],
            f"./bin/yb-admin --master_addresses {self.SECONDARY_MASTER} create_snapshot_schedule 1 10 ysql.yugabyte"
        )

        # Get table ID
        # Example output:
        # yugabyte.kv_store [ysql_schema=public] [000034cb000030008000000000004000]
        table_id_output = docker_check_output(
            self.PRIMARY_CONTAINER,
            f"./bin/yb-admin --master_addresses {self.PRIMARY_MASTER} list_tables | grep {self.DB}"
        )
        table_id = table_id_output.strip()
        # Extract the table ID from the output using regex
        table_id = re.search(r"\[([0-9a-f]+)\]$", table_id_output).group(1)

        print(f"Table ID: '{table_id}'")

        # Get bootstrap ID
        # Example output:
        # table id: 000034cb000030008000000000004000, CDC bootstrap id: de0b5affa1d0a6acbd42ab48a22e653f
        bootstrap_output = docker_check_output(
            self.PRIMARY_CONTAINER,
            f"./bin/yb-admin --master_addresses {self.PRIMARY_MASTER} bootstrap_cdc_producer {table_id}"
        )
        # Extract the bootstrap ID from the output using regex
        bootstrap_id = re.search(r"CDC bootstrap id: ([0-9a-f]+)", bootstrap_output).group(1)

        print(f"Bootstrap ID: '{bootstrap_id}'")

        # Set up universe replication on the first secondary
        docker_check_output(
            self.SECONDARY_CONTAINERS[0],
            f"./bin/yb-admin --master_addresses {self.SECONDARY_MASTER} setup_universe_replication kv_store_replication {self.PRIMARY_MASTER} {table_id} {bootstrap_id} transactional"
        )

        # Set the secondary cluster to STANDBY mode
        docker_check_output(
            self.SECONDARY_CONTAINERS[0],
            f"./bin/yb-admin --master_addresses {self.SECONDARY_MASTER} change_xcluster_role STANDBY"
        )

        safe_time_info = get_safe_time_info()
        print(safe_time_info)

    def __start_docker_compose(self):
        if self.is_running():
            raise Exception("Docker compose is already running")
        cmd = ["docker", "compose", "up", "--force-recreate"]
        self.__compose_process = Popen(cmd)
        time.sleep(5)
        if not self.is_running():
            raise Exception("Failed to start docker compose")

    def teardown(self):
        """Stop the docker compose process by sending SIGINT (Ctrl+C)."""
        if self.__compose_process:
            self.__compose_process.send_signal(signal.SIGINT)
            print("Sent SIGINT to docker compose. Waiting for it to exit...")
            self.__compose_process.wait()
            self.__compose_process = None


    def is_running(self):
        """Check if the docker compose process is still running.

        Returns:
            bool: True if running, False otherwise
        """
        if not self.__compose_process:
            return False
        return self.__compose_process.poll() is None


    def get_safe_time_info(self):
        """Get cross-cluster safe time info from the secondary cluster.

        Returns:
            dict: Dictionary containing:
                - namespace_id (str): ID of the namespace (e.g. '000034cb000030008000000000000000')
                - namespace_name (str): Name of the namespace (e.g. 'yugabyte')
                - safe_time (str): Safe time in human readable format (e.g. '2025-06-23 21:24:52.764103')
                - safe_time_epoch (str): Safe time in epoch microseconds (e.g. '1750713892764103')
                - safe_time_lag_sec (str): Lag in seconds between clusters (e.g. '0.64')
                - safe_time_skew_sec (str): Clock skew in seconds between clusters (e.g. '0.30')
        """
        safe_time_info = docker_check_output(
            self.SECONDARY_CONTAINERS[0],
            f"./bin/yb-admin --master_addresses {self.SECONDARY_MASTER} get_xcluster_safe_time include_lag_and_skew"
        )
        safe_time_info = json.loads(safe_time_info.strip())

        if len(safe_time_info) != 1:
            raise ValueError(f"Expected exactly 1 safe time info entry, got {len(safe_time_info)}")

        return safe_time_info[0]

# %%
def monitor_safe_time_stats(interval_sec=1, duration_sec=None):
    """Monitor safe time lag and skew statistics.

    Args:
        yb (YugabyteDB): YugabyteDB instance to monitor
        interval_sec (int): How often to check stats in seconds
        duration_sec (int, optional): How long to monitor for in seconds. If None, runs indefinitely.
    """
    max_lag = 0
    max_skew = 0
    start_time = time.time()

    try:
        while True:
            if duration_sec and time.time() - start_time > duration_sec:
                break

            info = get_safe_time_info()
            curr_lag = float(info["safe_time_lag_sec"])
            curr_skew = float(info["safe_time_skew_sec"])

            max_lag = max(max_lag, curr_lag)
            max_skew = max(max_skew, abs(curr_skew))

            print(f"Current lag: {curr_lag:.2f}s (max: {max_lag:.2f}s)")
            print(f"Current skew: {curr_skew:.2f}s (max: {max_skew:.2f}s)")
            print("-" * 50)

            time.sleep(interval_sec)

    except KeyboardInterrupt:
        print("\nStopping monitoring...")
        print(f"Final max lag: {max_lag:.2f}s")
        print(f"Final max skew: {max_skew:.2f}s")

monitor_safe_time_stats()
# Out:
# Current lag: 7.14s (max: 7.14s)
# Current skew: 7.02s (max: 7.02s)
# --------------------------------------------------
# Current lag: 8.26s (max: 8.26s)
# Current skew: 8.04s (max: 8.04s)
# --------------------------------------------------
# Current lag: 9.38s (max: 9.38s)
# Current skew: 8.97s (max: 8.97s)
# --------------------------------------------------
# Current lag: 10.49s (max: 10.49s)
# Current skew: 10.00s (max: 10.00s)
# --------------------------------------------------
# Current lag: 11.62s (max: 11.62s)
# Current skew: 11.03s (max: 11.03s)
# --------------------------------------------------
# Current lag: 12.73s (max: 12.73s)
# Current skew: 11.96s (max: 11.96s)
# --------------------------------------------------
# Current lag: 13.84s (max: 13.84s)
# Current skew: 12.98s (max: 12.98s)
# --------------------------------------------------
# Current lag: 14.96s (max: 14.96s)
# Current skew: 14.01s (max: 14.01s)
# --------------------------------------------------
# Current lag: 16.07s (max: 16.07s)
# Current skew: 15.97s (max: 15.97s)
# --------------------------------------------------
# Current lag: 17.19s (max: 17.19s)
# Current skew: 16.99s (max: 16.99s)
# --------------------------------------------------
# Current lag: 18.30s (max: 18.30s)
# Current skew: 18.03s (max: 18.03s)
# --------------------------------------------------
# Current lag: 19.42s (max: 19.42s)
# Current skew: 19.06s (max: 19.06s)
# --------------------------------------------------
# Current lag: 20.53s (max: 20.53s)
# Current skew: 19.99s (max: 19.99s)
# --------------------------------------------------
# Current lag: 21.65s (max: 21.65s)
# Current skew: 21.02s (max: 21.02s)
# --------------------------------------------------
# Current lag: 22.77s (max: 22.77s)
# Current skew: 22.05s (max: 22.05s)
# --------------------------------------------------
# Current lag: 23.89s (max: 23.89s)
# Current skew: 22.98s (max: 22.98s)
# --------------------------------------------------
# Current lag: 25.00s (max: 25.00s)
# Current skew: 24.01s (max: 24.01s)
# --------------------------------------------------
# Current lag: 26.13s (max: 26.13s)
# Current skew: 26.07s (max: 26.07s)
# --------------------------------------------------
# Current lag: 27.24s (max: 27.24s)
# Current skew: 27.00s (max: 27.00s)
# --------------------------------------------------
# Current lag: 28.36s (max: 28.36s)
# Current skew: 28.03s (max: 28.03s)
# --------------------------------------------------
# Current lag: 29.47s (max: 29.47s)
# Current skew: 29.06s (max: 29.06s)
# --------------------------------------------------
# Current lag: 30.59s (max: 30.59s)
# Current skew: 30.07s (max: 30.07s)
# --------------------------------------------------
# Current lag: 31.71s (max: 31.71s)
# Current skew: 31.00s (max: 31.00s)
# --------------------------------------------------
# Current lag: 32.84s (max: 32.84s)
# Current skew: 32.02s (max: 32.02s)
# --------------------------------------------------
# Current lag: 33.95s (max: 33.95s)
# Current skew: 33.05s (max: 33.05s)
# --------------------------------------------------
# Current lag: 35.08s (max: 35.08s)
# Current skew: 34.07s (max: 34.07s)
# --------------------------------------------------
# Current lag: 36.20s (max: 36.20s)
# Current skew: 36.02s (max: 36.02s)
# --------------------------------------------------
# Current lag: 37.32s (max: 37.32s)
# Current skew: 37.05s (max: 37.05s)
# --------------------------------------------------
# Current lag: 38.43s (max: 38.43s)
# Current skew: 38.08s (max: 38.08s)
# --------------------------------------------------
# Current lag: 39.55s (max: 39.55s)
# Current skew: 39.00s (max: 39.00s)
# --------------------------------------------------
# Current lag: 40.67s (max: 40.67s)
# Current skew: 40.02s (max: 40.02s)
# --------------------------------------------------
# Current lag: 41.79s (max: 41.79s)
# Current skew: 41.04s (max: 41.04s)
# --------------------------------------------------
# Current lag: 42.90s (max: 42.90s)
# Current skew: 42.08s (max: 42.08s)
# --------------------------------------------------
# Current lag: 44.02s (max: 44.02s)
# Current skew: 43.09s (max: 43.09s)
# --------------------------------------------------
# Current lag: 45.15s (max: 45.15s)
# Current skew: 45.05s (max: 45.05s)
# --------------------------------------------------
# Current lag: 46.26s (max: 46.26s)
# Current skew: 46.08s (max: 46.08s)
# --------------------------------------------------
# Current lag: 47.38s (max: 47.38s)
# Current skew: 47.10s (max: 47.10s)
# --------------------------------------------------
# Current lag: 48.49s (max: 48.49s)
# Current skew: 48.03s (max: 48.03s)
# --------------------------------------------------
# Current lag: 49.61s (max: 49.61s)
# Current skew: 49.06s (max: 49.06s)
# --------------------------------------------------
# Current lag: 50.73s (max: 50.73s)
# Current skew: 50.08s (max: 50.08s)
# --------------------------------------------------
# Current lag: 51.84s (max: 51.84s)
# Current skew: 51.01s (max: 51.01s)
# --------------------------------------------------
# Current lag: 52.95s (max: 52.95s)
# Current skew: 52.03s (max: 52.03s)
# --------------------------------------------------
# Current lag: 54.06s (max: 54.06s)
# Current skew: 53.09s (max: 53.09s)
# --------------------------------------------------
# Current lag: 55.18s (max: 55.18s)
# Current skew: 55.04s (max: 55.04s)
# --------------------------------------------------
# Current lag: 56.29s (max: 56.29s)
# Current skew: 56.07s (max: 56.07s)
# --------------------------------------------------
# Current lag: 57.41s (max: 57.41s)
# Current skew: 57.09s (max: 57.09s)
# --------------------------------------------------
# Current lag: 58.54s (max: 58.54s)
# Current skew: 58.09s (max: 58.09s)
# --------------------------------------------------
# Current lag: 59.66s (max: 59.66s)
# Current skew: 59.12s (max: 59.12s)
# --------------------------------------------------
# Current lag: 60.79s (max: 60.79s)
# Current skew: 60.07s (max: 60.07s)
# --------------------------------------------------
# Current lag: 61.91s (max: 61.91s)
# Current skew: 61.10s (max: 61.10s)
# --------------------------------------------------
# Current lag: 63.02s (max: 63.02s)
# Current skew: 62.09s (max: 62.09s)
# --------------------------------------------------
# Current lag: 64.13s (max: 64.13s)
# Current skew: 64.07s (max: 64.07s)
# --------------------------------------------------
# Current lag: 65.25s (max: 65.25s)
# Current skew: 65.10s (max: 65.10s)
# --------------------------------------------------
# Current lag: 66.37s (max: 66.37s)
# Current skew: 66.12s (max: 66.12s)
# --------------------------------------------------
# Current lag: 67.49s (max: 67.49s)
# Current skew: 67.11s (max: 67.11s)
# --------------------------------------------------
# Current lag: 68.60s (max: 68.60s)
# Current skew: 68.07s (max: 68.07s)
# --------------------------------------------------
# Current lag: 69.72s (max: 69.72s)
# Current skew: 69.10s (max: 69.10s)
# --------------------------------------------------
# Current lag: 70.83s (max: 70.83s)
# Current skew: 70.12s (max: 70.12s)
# --------------------------------------------------
# Current lag: 71.95s (max: 71.95s)
# Current skew: 71.11s (max: 71.11s)
# --------------------------------------------------
# Current lag: 73.07s (max: 73.07s)
# Current skew: 72.07s (max: 72.07s)
# --------------------------------------------------
# Current lag: 74.18s (max: 74.18s)
# Current skew: 74.12s (max: 74.12s)
# --------------------------------------------------
# Current lag: 75.30s (max: 75.30s)
# Current skew: 75.14s (max: 75.14s)
# --------------------------------------------------
# Current lag: 76.42s (max: 76.42s)
# Current skew: 76.06s (max: 76.06s)
# --------------------------------------------------
# Current lag: 77.53s (max: 77.53s)
# Current skew: 77.08s (max: 77.08s)
# --------------------------------------------------
# Current lag: 78.65s (max: 78.65s)
# Current skew: 78.11s (max: 78.11s)
# --------------------------------------------------
# Current lag: 79.76s (max: 79.76s)
# Current skew: 79.14s (max: 79.14s)
# --------------------------------------------------
# Current lag: 80.89s (max: 80.89s)
# Current skew: 80.06s (max: 80.06s)
# --------------------------------------------------
# Current lag: 82.01s (max: 82.01s)
# Current skew: 81.10s (max: 81.10s)
# --------------------------------------------------
# Current lag: 83.13s (max: 83.13s)
# Current skew: 82.12s (max: 82.12s)
# --------------------------------------------------
# Current lag: 84.24s (max: 84.24s)
# Current skew: 84.07s (max: 84.07s)
# --------------------------------------------------
# Current lag: 85.36s (max: 85.36s)
# Current skew: 85.09s (max: 85.09s)
# --------------------------------------------------
# Current lag: 86.48s (max: 86.48s)
# Current skew: 86.11s (max: 86.11s)
# --------------------------------------------------
# Current lag: 87.60s (max: 87.60s)
# Current skew: 87.15s (max: 87.15s)
# --------------------------------------------------
# Current lag: 88.72s (max: 88.72s)
# Current skew: 88.07s (max: 88.07s)
# --------------------------------------------------
# Current lag: 89.85s (max: 89.85s)
# Current skew: 89.10s (max: 89.10s)
# --------------------------------------------------
# Current lag: 90.97s (max: 90.97s)
# Current skew: 90.12s (max: 90.12s)
# --------------------------------------------------
# Current lag: 92.09s (max: 92.09s)
# Current skew: 91.15s (max: 91.15s)
# --------------------------------------------------
# Current lag: 93.20s (max: 93.20s)
# Current skew: 93.11s (max: 93.11s)
# --------------------------------------------------
# Current lag: 94.33s (max: 94.33s)
# Current skew: 94.14s (max: 94.14s)
# --------------------------------------------------
# Current lag: 95.45s (max: 95.45s)
# Current skew: 95.16s (max: 95.16s)
# --------------------------------------------------
# Current lag: 96.57s (max: 96.57s)
# Current skew: 96.09s (max: 96.09s)
# --------------------------------------------------
# Current lag: 97.69s (max: 97.69s)
# Current skew: 97.11s (max: 97.11s)
# --------------------------------------------------
# Current lag: 98.81s (max: 98.81s)
# Current skew: 98.14s (max: 98.14s)
# --------------------------------------------------
# Current lag: 99.92s (max: 99.92s)
# Current skew: 99.17s (max: 99.17s)
# --------------------------------------------------
# Current lag: 101.04s (max: 101.04s)
# Current skew: 100.10s (max: 100.10s)
# --------------------------------------------------
# Current lag: 102.15s (max: 102.15s)
# Current skew: 101.12s (max: 101.12s)
# --------------------------------------------------
# Current lag: 103.27s (max: 103.27s)
# Current skew: 103.08s (max: 103.08s)
# --------------------------------------------------
# Current lag: 104.39s (max: 104.39s)
# Current skew: 104.11s (max: 104.11s)
# --------------------------------------------------
# Current lag: 105.51s (max: 105.51s)
# Current skew: 105.13s (max: 105.13s)
# --------------------------------------------------
# Current lag: 106.62s (max: 106.62s)
# Current skew: 106.16s (max: 106.16s)
# --------------------------------------------------
# Current lag: 107.74s (max: 107.74s)
# Current skew: 107.09s (max: 107.09s)
# --------------------------------------------------
# Current lag: 108.86s (max: 108.86s)
# Current skew: 108.12s (max: 108.12s)
# --------------------------------------------------
# Current lag: 109.97s (max: 109.97s)
# Current skew: 109.16s (max: 109.16s)
# --------------------------------------------------
# Current lag: 111.08s (max: 111.08s)
# Current skew: 110.18s (max: 110.18s)
# --------------------------------------------------
# Current lag: 112.20s (max: 112.20s)
# Current skew: 112.14s (max: 112.14s)
# --------------------------------------------------
# Current lag: 113.31s (max: 113.31s)
# Current skew: 113.18s (max: 113.18s)
# --------------------------------------------------
# Current lag: 114.43s (max: 114.43s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 115.54s (max: 115.54s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 116.66s (max: 116.66s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 117.78s (max: 117.78s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 118.90s (max: 118.90s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 120.02s (max: 120.02s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 121.13s (max: 121.13s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# Current lag: 122.26s (max: 122.26s)
# Current skew: 114.19s (max: 114.19s)
# --------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 36
#      33         print(f"Final max lag: {max_lag:.2f}s")
#      34         print(f"Final max skew: {max_skew:.2f}s")
# ---> 36 monitor_safe_time_stats()
#
# Cell In[43], line 18, in monitor_safe_time_stats(interval_sec, duration_sec)
#      15 if duration_sec and time.time() - start_time > duration_sec:
#      16     break
# ---> 18 info = get_safe_time_info()
#      19 curr_lag = float(info["safe_time_lag_sec"])
#      20 curr_skew = float(info["safe_time_skew_sec"])
#
# Cell In[33], line 23, in get_safe_time_info()
#      20 safe_time_info = json.loads(safe_time_info.strip())
#      22 if len(safe_time_info) != 1:
# ---> 23     raise ValueError(f"Expected exactly 1 safe time info entry, got {len(safe_time_info)}")
#      25 return safe_time_info[0]
#
# ValueError: Expected exactly 1 safe time info entry, got 0
